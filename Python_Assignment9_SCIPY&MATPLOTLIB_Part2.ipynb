# %% [markdown]
# 1. Create a pie chart presenting the male/female proportion# Create a pie chart presenting the male/female proportion

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
titanic1 = pd.read_csv('https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv')
female = len(titanic1[titanic1.sex=='female'])
male = len(titanic1[titanic1.sex=='male'])
fig = plt.figure()
chart1 = fig.add_subplot(1,1,1)
chart1.axis('equal')
chart1.pie([female, male],labels=['female','male'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0xbec2e30>,
#   <matplotlib.patches.Wedge at 0xbed9310>],
#  [Text(0.480837,0.989341,'female'), Text(-0.480837,-0.989341,'male')],
#  [Text(0.262275,0.539641,'35.6%'), Text(-0.262275,-0.539641,'64.4%')])

# %% [markdown]
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
titanic = pd.read_csv('https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv')
cond = titanic.sex == 'female'
subset_a = titanic[cond]
subset_b = titanic[~cond]
plt.figure(figsize=(20, 15))
plt.scatter(subset_a.fare, subset_a.age, c='b', label='female')
plt.scatter(subset_b.fare, subset_b.age, c='r', label='male') 
plt.title("Fare paid and Age, differed the plot color by Gender")
plt.xlabel("Fare Paid")
plt.ylabel("Age")
plt.legend()
